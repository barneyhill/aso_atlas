# %%
import sys
from pathlib import Path

# Add the project root to the Python path
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import pandas as pd

# Now load the dataset
df = pd.read_pickle('../data/aso_atlas.pkl')

# View schema
print(df.columns)
print(f"\nDataset shape: {df.shape}")
df.head()
# Out:
# Index(['aso_sequence_5_to_3', 'inhibition_percent', 'chemistry', 'custom_id',
#        'target_mrna', 'target_gene', 'cell_line', 'cell_line_species',
#        'dosage', 'cells_per_well', 'transfection_method', 'steric_blocking'],
#       dtype='object')
#
# Dataset shape: (190927, 12)
#     aso_sequence_5_to_3  inhibition_percent  \
# 0  GCAGATATTTCAATATACAG                84.0
# 1  GCTCATTATCTCATTTGACT                46.0
# 2  GCTGACAAACTGTACTGGGT                69.0
# 3  CCACTCAATATCCTACCTCT                44.0
# 4  CTACAGGTTTTCCCCACATC                53.0
#
#                                            chemistry  \
# 0  length=20 modifications=[Modification(modifica...
# 1  length=20 modifications=[Modification(modifica...
# 2  length=20 modifications=[Modification(modifica...
# 3  length=20 modifications=[Modification(modifica...
# 4  length=20 modifications=[Modification(modifica...
#
#                                            custom_id target_mrna target_gene  \
# 0  patent-scrape-v2/data/inhibition_tables/US2023...         APP         APP
# 1  patent-scrape-v2/data/inhibition_tables/US2023...         APP         APP
# 2  patent-scrape-v2/data/inhibition_tables/US2023...         APP         APP
# 3  patent-scrape-v2/data/inhibition_tables/US2023...         APP         APP
# 4  patent-scrape-v2/data/inhibition_tables/US2023...         APP         APP
#
#   cell_line cell_line_species  dosage cells_per_well transfection_method  \
# 0   SH-SY5Y             human  4000.0          20000     Electroporation
# 1   SH-SY5Y             human  4000.0          20000     Electroporation
# 2   SH-SY5Y             human  4000.0          20000     Electroporation
# 3   SH-SY5Y             human  4000.0          20000     Electroporation
# 4   SH-SY5Y             human  4000.0          20000     Electroporation
#
#    steric_blocking
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
